# %% [markdown]
# <a href="https://colab.research.google.com/github/khadijakatanani/Data-Science/blob/main/Week_10_ANNs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #########################################################################
# # Artificial Neural Network - Video Game Success Prediction
# #########################################################################

# %% [markdown]
# ## Business Problem
#
# The task of the project is to build an artificial neural network which will be trained to predict whether or not a video game player will successfully complete a task in the game or not.

# %% [markdown]
# ### Import Libraries

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### Import Libraries => Keras Implementation
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Sequence of Pre-Processing Tasks

# %% [markdown]
# * Import Data
# * Drop any redundant columns
# * Split Input Variables & Output Variable
# * Split out Training & Test sets

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Deal with Categorical Variables

# %%
# Just execute the cell

categorical_vars = ["clan"]

one_hot_encoder = OneHotEncoder(sparse=False, drop = "first")

X_train_encoded = one_hot_encoder.fit_transform(X_train[categorical_vars])
X_test_encoded = one_hot_encoder.transform(X_test[categorical_vars])

encoder_feature_names = one_hot_encoder.get_feature_names_out(categorical_vars)

X_train_encoded = pd.DataFrame(X_train_encoded, columns = encoder_feature_names)
X_train = pd.concat([X_train.reset_index(drop=True), X_train_encoded.reset_index(drop=True)], axis = 1)
X_train.drop(categorical_vars, axis = 1, inplace = True)

X_test_encoded = pd.DataFrame(X_test_encoded, columns = encoder_feature_names)
X_test = pd.concat([X_test.reset_index(drop=True), X_test_encoded.reset_index(drop=True)], axis = 1)
X_test.drop(categorical_vars, axis = 1, inplace = True)

# %% [markdown]
# ### Feature Scaling

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Network Architecture

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### compile network

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### view network architecture

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Train The Network!

# %% [markdown]
# ### training hyperparameters

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### callbacks - ModelCheckpoint

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### train the network

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Visualise Training & Validation Performance

# %%
# just run the cell

import matplotlib.pyplot as plt

# plot metrics by epoch
fig, ax = plt.subplots(2, 1, figsize=(15,15))
ax[0].set_title('Loss')
ax[0].plot(history.epoch, history.history["loss"], label="Training Loss")
ax[0].plot(history.epoch, history.history["val_loss"], label="Validation Loss")
ax[1].set_title('Accuracy')
ax[1].plot(history.epoch, history.history["accuracy"], label="Training Accuracy")
ax[1].plot(history.epoch, history.history["val_accuracy"], label="Validation Accuracy")
ax[0].legend()
ax[1].legend()
plt.show()

# get best epoch performance for validation accuracy
max(history.history['val_accuracy'])

# %% [markdown]
# # Make Predictions On New Data

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### create new data

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### make our prediction

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #########################################################################
# # QUIZ
# #########################################################################

# %% [markdown]
# ## Q1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### A1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Q2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### A2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Q3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### A3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Q4

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### A4

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Q5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### A5

# %% [markdown]
# ![image.png](data:image/png;base64,...)
